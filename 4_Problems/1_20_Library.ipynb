# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_20_Library.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🟩 List Installed Packages (1.20.1)
#
# **Problem Statement:**
# List all installed packages in your current Google Colab environment using pip.
#
# **Hint:**
# Use the <code>!pip list</code> command to list all installed packages.

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- ------------
# aiobotocore                       2.7.0
# aiohttp                           3.9.3
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.12
# altair                            5.0.1
# anaconda-anon-usage               0.4.3
# anaconda-catalogs                 0.2.0
# anaconda-client                   1.12.3
# anaconda-cloud-auth               0.1.4
# anaconda-navigator                2.5.2
# anaconda-project                  0.11.1
# anyio                             4.2.0
# appdirs                           1.4.4
# archspec                          0.2.3
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.2.3
# astroid                           2.14.2
# astropy                           5.3.4
# asttokens                         2.0.5
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Install and Verify Library (1.20.2)
#
# **Problem Statement:**
# Install a third-party library named <code>pyjokes</code> using <code>pip</code>.
#
# Verify its installation by importing it in and then running the method <code>get_jokes()</code>.
#
# **Hint:**
# Use the <code>!pip install</code> command to install the library.
#
# Use . notation to access the method <code>get_jokes()</code> of <code>pyjokes</code>.

# %%
import pyjokes

pyjokes.get_joke()
# Out:
# "Two bytes meet. The first byte asks, 'Are you ill?' The second byte replies, 'No, just feeling a bit off.'"

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 List Files in Directory (1.20.3)
#
# **Problem Statement:**
# Use the os library to list all files in the current directory and print their names with the function <code>os.listdir('.')</code>.
#
# **Hint:**
# Use the <code>os.listdir</code> function to get the list of files in the current directory, which is denoted by:

# %%
import os

os.listdir('.')
# Out:
# ['1_02.1_Python Terms.ipynb',
#  '1_02_Variables.ipynb',
#  '1_03_Data Types.ipynb',
#  '1_04_Strings.ipynb',
#  '1_05_String Formatting.ipynb',
#  '1_06_Operators Part 1.ipynb',
#  '1_07_Conditional Statements.ipynb',
#  '1_08_Lists.ipynb',
#  '1_09_Dictionaries.ipynb',
#  '1_10_Sets.ipynb',
#  '1_11_Tuples.ipynb',
#  '1_12_Operators Part 2.ipynb',
#  '1_13_Loops.ipynb',
#  '1_14_List Comprehensions.ipynb',
#  '1_16_Functions.ipynb',
#  '1_17_Lambda.ipynb',
#  '1_18_Modules.ipynb',
#  '1_20_Library.ipynb',
#  '1_21_Classes.ipynb',
#  '1_22_NumPy.ipynb',
#  '1_23_Pandas Intro.ipynb',
#  '1_24_Pandas Inspection.ipynb',
#  '1_25_Pandas Cleaning.ipynb',
#  '1_26_Pandas Analysis.ipynb',
#  '1_28_Matplotlib Intro.ipynb',
#  '1_29_Matplotlib Plotting.ipynb',
#  '1_30_Matplotlib Labeling.ipynb',
#  '1_31_Matplotlib Pandas Plotting.ipynb',
#  '2_01_Pandas Accessing Data.ipynb',
#  '2_02_Pandas Data Cleaning.ipynb',
#  '2_03_Pandas Data Management.ipynb',
#  '2_04_Pandas Pivot Tables.ipynb',
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Fetch Data from URL (1.20.4)
#
# **Problem Statement:**
# Use the <code>requests</code> library to fetch data from the URL 'https://pokeapi.co/api/v2/pokemon/pikachu' and print the JSON response.
#
# **Hint:**
# Use the <code>requests.get()</code> function to fetch data from the URL, providing url as the argument; this will provide a response object.
# With the response object, use the <code>json</code> method to get the response formatted as json.

# %%
import requests
# Code Needed
url = 'https://pokeapi.co/api/v2/pokemon/pikachu'
dataget = requests.get(url).json()
dataget
# Out:
# {'abilities': [{'ability': {'name': 'static',
#     'url': 'https://pokeapi.co/api/v2/ability/9/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'lightning-rod',
#     'url': 'https://pokeapi.co/api/v2/ability/31/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 112,
#  'cries': {'latest': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/latest/25.ogg',
#   'legacy': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/legacy/25.ogg'},
#  'forms': [{'name': 'pikachu',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/25/'}],
#  'game_indices': [{'game_index': 84,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 84,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 84,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 25,
# ...

# %% [markdown]
# ---
